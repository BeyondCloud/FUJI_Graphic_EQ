# %%
import scipy.signal as signal
import matplotlib.pyplot as plt
import numpy as np

# temp needs to be converted from a "list" into a numpy array...
r =np.random.randn(60,)
t = np.arange(0,6,0.1)
sig = np.sin(t)
temp = 2.0+sig+r*0.1
plt.plot(temp)
plt.show()
print(len(t))
# Out:
# 60
